# %% [markdown]
# # Project Title-Predicting Hospital Readmission for Patients With Diabetics

# %%
import os
os.chdir("C:\\Users\\SriKavyaChintalapudi\\Desktop\\remote internship 2020\\python code")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\SriKavyaChintalapudi\\Desktop\\remote internship 2020\\python code'

# %% [markdown]
# # DATA PREPROCESSING

# %% [markdown]
# # Importing Libraries

# %%
import pandas as pd 
from sklearn import preprocessing 
data1=pd.read_csv("readmission.csv")

# %% [markdown]
# # Importing Dataset

# %%
data1
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
# ...

# %% [markdown]
# # Data Visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data1=pd.read_csv("readmission.csv")
data1
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
# ...

# %%
data1.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %%
data1.describe()
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  1.017660e+05  1.017660e+05      101766.000000
# mean   1.652016e+08  5.433040e+07           2.024006
# std    1.026403e+08  3.869636e+07           1.445403
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    8.496119e+07  2.341322e+07           1.000000
# 50%    1.523890e+08  4.550514e+07           1.000000
# 75%    2.302709e+08  8.754595e+07           3.000000
# max    4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# ...

# %%
data1.cov()
# Out:
#                           encounter_id   patient_nbr  admission_type_id  \
# encounter_id              1.053503e+16  2.033677e+15      -2.358289e+07
# patient_nbr               2.033677e+15  1.497408e+15      -6.224166e+05
# admission_type_id        -2.358289e+07 -6.224166e+05       2.089189e+00
# discharge_disposition_id -7.201319e+07 -2.795424e+07       6.371413e-01
# admission_source_id      -4.688716e+07 -5.121875e+06       6.265112e-01
# time_in_hospital         -1.906392e+07 -2.782956e+06      -5.393206e-02
# num_lab_procedures       -5.262982e+07  1.214034e+07      -4.086834e+00
# num_procedures           -2.490548e+06 -1.027757e+06       3.202480e-01
# num_medications           6.349488e+07  6.499150e+06       9.343452e-01
# number_outpatient         1.349577e+07  5.069566e+06       4.855953e-02
# number_emergency          7.907967e+06  2.245038e+06      -2.570937e-02
# number_inpatient          4.013309e+06  6.098915e+05      -6.965742e-02
# ...

# %%
data1.corr()
# Out:
#                           encounter_id  patient_nbr  admission_type_id  \
# encounter_id                  1.000000     0.512028          -0.158961
# patient_nbr                   0.512028     1.000000          -0.011128
# admission_type_id            -0.158961    -0.011128           1.000000
# discharge_disposition_id     -0.132876    -0.136814           0.083483
# admission_source_id          -0.112402    -0.032568           0.106654
# time_in_hospital             -0.062221    -0.024092          -0.012500
# num_lab_procedures           -0.026062     0.015946          -0.143713
# num_procedures               -0.014225    -0.015570           0.129888
# num_medications               0.076113     0.020665           0.079535
# number_outpatient             0.103756     0.103379           0.026511
# number_emergency              0.082803     0.062352          -0.019116
# number_inpatient              0.030962     0.012480          -0.038161
# ...

# %%
data1.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
data1.dtypes
# Out:
# encounter_id                 int64
# patient_nbr                  int64
# race                        object
# gender                      object
# age                         object
# weight                      object
# admission_type_id            int64
# discharge_disposition_id     int64
# admission_source_id          int64
# time_in_hospital             int64
# payer_code                  object
# medical_specialty           object
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# ...

# %%
import matplotlib
# %matplotlib inline

# %%
data1['diag_1'].hist(bins=10)

# %%
data1['diag_2'].hist(bins=10)

# %%
data1['diag_3'].hist(bins=10)

# %%
data1['number_diagnoses'].hist(bins=10)

# %%
data1['max_glu_serum'].hist(bins=10)

# %%
data1['A1Cresult'].hist(bins=10)

# %%
data1['insulin'].hist(bins=10)

# %%
data1['diabetesMed'].hist(bins=10)

# %%
data1['readmitted'].hist(bins=10)

# %%
data1.boxplot(column='number_diagnoses')

# %%
data1.boxplot(column='readmitted')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-8ab3a849f69d> in <module>
# ----> 1 data1.boxplot(column='readmitted')
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     445         layout=layout,
#     446         return_type=return_type,
# --> 447         **kwargs,
#     448     )
#     449
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\boxplot.py in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     373         layout=layout,
#     374         return_type=return_type,
# --> 375         **kwds,
#     376     )
#     377     plt.draw_if_interactive()
#
# ...

# %%
import seaborn as sns
sns.heatmap(df.corr())

# %%
data1.isnull()
# Out:
#         encounter_id  patient_nbr   race  gender    age  weight  \
# 0              False        False  False   False  False   False
# 1              False        False  False   False  False   False
# 2              False        False  False   False  False   False
# 3              False        False  False   False  False   False
# 4              False        False  False   False  False   False
# ...              ...          ...    ...     ...    ...     ...
# 101761         False        False  False   False  False   False
# 101762         False        False  False   False  False   False
# 101763         False        False  False   False  False   False
# 101764         False        False  False   False  False   False
# 101765         False        False  False   False  False   False
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                   False                     False                False
# ...

# %%
data1['diabetesMed'].value_counts()
# Out:
# Yes    78363
# No     23403
# Name: diabetesMed, dtype: int64

# %%
data1['readmitted'].value_counts()
# Out:
# NO     54864
# >30    35545
# <30    11357
# Name: readmitted, dtype: int64

# %%
sns.jointplot(data1['insulin'],data1['number_diagnoses'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-71-05f2b78b5be2> in <module>
# ----> 1 sns.jointplot(data1['insulin'],data1['number_diagnoses'])
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2299         marginal_kws.setdefault("kde", False)
#    2300         marginal_kws.setdefault("color", color)
# -> 2301         grid.plot_marginals(distplot, **marginal_kws)
#    2302
#    2303     elif kind.startswith("hex"):
#
# ~\anaconda3\lib\site-packages\seaborn\axisgrid.py in plot_marginals(self, func, **kwargs)
#    1808         kwargs["vertical"] = False
#    1809         plt.sca(self.ax_marg_x)
# -> 1810         func(self.x, **kwargs)
#    1811
#    1812         kwargs["vertical"] = True
#
# ...

# %%
#scatter plot
plt.scatter(data1['number_diagnoses'],data1['number_emergency'],color='g')
plt.title("Numerical Feature: number_diagnoses v/s number_emergency")
plt.xlabel("number_diagnoses")
plt.ylabel("number_emergency")
# Out:
# Text(0, 0.5, 'number_emergency')

# %%
#scatter plot
plt.scatter(data1['number_inpatient'],data1['num_medications'],color='y')
plt.title("Numerical Feature: number_inpatient v/s num_medications")
plt.xlabel("number_inpatient")
plt.ylabel("num_medications")
# Out:
# Text(0, 0.5, 'num_medications')

# %%
sns.jointplot(data1['number_diagnoses'],data1['number_emergency'])

# %% [markdown]
# # Taking Care of Missing Data

# %%
import os
os.getcwd()
os.chdir("C:\\Users\\SriKavyaChintalapudi\\Desktop\\remote internship 2020\\python code")
os.getcwd()
# Out:
# 'C:\\Users\\SriKavyaChintalapudi\\Desktop\\remote internship 2020\\python code'

# %%
import numpy as np
import pandas as pd   # importing libraries

# %%
#data importing
data1=pd.read_csv("readmission.csv")

# %%
data1
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
# ...

# %%
data1.dtypes
# Out:
# encounter_id                 int64
# patient_nbr                  int64
# race                        object
# gender                      object
# age                         object
# weight                      object
# admission_type_id            int64
# discharge_disposition_id     int64
# admission_source_id          int64
# time_in_hospital             int64
# payer_code                  object
# medical_specialty           object
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# ...

# %%
data1.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
data1.describe()
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  1.017660e+05  1.017660e+05      101766.000000
# mean   1.652016e+08  5.433040e+07           2.024006
# std    1.026403e+08  3.869636e+07           1.445403
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    8.496119e+07  2.341322e+07           1.000000
# 50%    1.523890e+08  4.550514e+07           1.000000
# 75%    2.302709e+08  8.754595e+07           3.000000
# max    4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# ...

# %%
for col in data1.columns:
    if data1[col].dtype == object:
         print(col,data1[col][data1[col] == '?'].count())
# Out:
# race 0
# gender 0
# age 0
# weight 93449
# payer_code 38273
# medical_specialty 47524
# diag_1 0
# diag_2 0
# diag_3 0
# max_glu_serum 0
# A1Cresult 0
# metformin 0
# repaglinide 0
# nateglinide 0
# chlorpropamide 0
# glimepiride 0
# acetohexamide 0
# glipizide 0
# glyburide 0
# tolbutamide 0
# pioglitazone 0
# rosiglitazone 0
# acarbose 0
# miglitol 0
# troglitazone 0
# tolazamide 0
# examide 0
# citoglipton 0
# insulin 0
# glyburide-metformin 0
# glipizide-metformin 0
# glimepiride-pioglitazone 0
# metformin-rosiglitazone 0
# metformin-pioglitazone 0
# change 0
# diabetesMed 0
# readmitted 0

# %%
print('gender', data1['gender'][data1['gender'] == 'Unknown/Invalid'].count())
# Out:
# gender 0

# %%
daat1 = data1.drop(['weight','payer_code','medical_specialty',], axis = 1)
data1
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
# ...

# %%
drop_Idx = set(data1[(data1['diag_1'] == '?') & (data1['diag_2'] == '?') & (data1['diag_3'] == '?')].index)

drop_Idx = drop_Idx.union(set(data1['diag_1'][data1['diag_1'] == '?'].index))
drop_Idx = drop_Idx.union(set(data1['diag_2'][data1['diag_2'] == '?'].index))
drop_Idx = drop_Idx.union(set(data1['diag_3'][data1['diag_3'] == '?'].index))
drop_Idx = drop_Idx.union(set(data1['race'][data1['race'] == '?'].index))
drop_Idx = drop_Idx.union(set(data1[data1['discharge_disposition_id'] == 11].index))
drop_Idx = drop_Idx.union(set(data1['gender'][data1['gender'] == 'Unknown/Invalid'].index))
new_Idx = list(set(data1.index) - set(drop_Idx))
data1 = data1.iloc[new_Idx]

# %%
for col in data1.columns:
    if data1[col].dtype == object:
         print(col,data1[col][data1[col] == '?'].count())
            
print('gender', data1['gender'][data1['gender'] == 'Unknown/Invalid'].count())
# Out:
# race 0
# gender 0
# age 0
# weight 93449
# payer_code 38273
# medical_specialty 47524
# diag_1 0
# diag_2 0
# diag_3 0
# max_glu_serum 0
# A1Cresult 0
# metformin 0
# repaglinide 0
# nateglinide 0
# chlorpropamide 0
# glimepiride 0
# acetohexamide 0
# glipizide 0
# glyburide 0
# tolbutamide 0
# pioglitazone 0
# rosiglitazone 0
# acarbose 0
# miglitol 0
# troglitazone 0
# tolazamide 0
# examide 0
# citoglipton 0
# insulin 0
# glyburide-metformin 0
# glipizide-metformin 0
# glimepiride-pioglitazone 0
# metformin-rosiglitazone 0
# metformin-pioglitazone 0
# change 0
# diabetesMed 0
# readmitted 0
# gender 0

# %%
data1.fillna(data1.mean(),inplace=True)
# Out:
# C:\Users\SriKavyaChintalapudi\anaconda3\lib\site-packages\pandas\core\generic.py:6245: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._update_inplace(new_data)

# %%
data1 = data1.drop(['weight','payer_code','medical_specialty',], axis = 1)
data1
# Out:
#         encounter_id  patient_nbr             race  gender      age  \
# 1             149190     55629189        Caucasian  Female  [10-20)
# 2              64410     86047875  AfricanAmerican  Female  [20-30)
# 3             500364     82442376        Caucasian    Male  [30-40)
# 4              16680     42519267        Caucasian    Male  [40-50)
# 5              35754     82637451        Caucasian    Male  [50-60)
# ...              ...          ...              ...     ...      ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)
# 101763     443854148     41088789        Caucasian    Male  [70-80)
# 101764     443857166     31693671        Caucasian  Female  [80-90)
# 101765     443867222    175429310        Caucasian    Male  [70-80)
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 1                       1                         1                    7
# ...

# %%
data1
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
# ...

# %%
# After imputation Get a count of missing values in the dataset
data1.apply(lambda x: sum(x.isnull()),axis=0)
# Out:
# patient_nbr                 0
# race                        0
# gender                      0
# age                         0
# admission_type_id           0
# discharge_disposition_id    0
# admission_source_id         0
# time_in_hospital            0
# payer_code                  0
# medical_specialty           0
# num_lab_procedures          0
# num_procedures              0
# num_medications             0
# number_outpatient           0
# number_emergency            0
# number_inpatient            0
# diag_1                      0
# diag_2                      0
# diag_3                      0
# number_diagnoses            0
# max_glu_serum               0
# A1Cresult                   0
# metformin                   0
# repaglinide                 0
# nateglinide                 0
# chlorpropamide              0
# glimepiride                 0
# acetohexamide               0
# glipizide                   0
# glyburide                   0
# tolbutamide                 0
# ...

# %%
data1
# Out:
#         patient_nbr             race  gender      age  admission_type_id  \
# 0           8222157        Caucasian  Female   [0-10)                  6
# 1          55629189        Caucasian  Female  [10-20)                  1
# 2          86047875  AfricanAmerican  Female  [20-30)                  1
# 3          82442376        Caucasian    Male  [30-40)                  1
# 4          42519267        Caucasian    Male  [40-50)                  1
# ...             ...              ...     ...      ...                ...
# 101761    100162476  AfricanAmerican    Male  [70-80)                  1
# 101762     74694222  AfricanAmerican  Female  [80-90)                  1
# 101763     41088789        Caucasian    Male  [70-80)                  1
# 101764     31693671        Caucasian  Female  [80-90)                  2
# 101765    175429310        Caucasian    Male  [70-80)                  1
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# ...

# %%
data1.fillna(data1.mean(),inplace=True)

# %%
data1
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
# ...

# %%
data1 = data1.drop(columns=['weight','encounter_id'])

# %%
data1 = data1.drop(columns=['payer_code','medical_specialty'])

# %%
data1 = data1.drop(columns=['race'])

# %%
data1
# Out:
#         encounter_id  patient_nbr  gender      age weight  admission_type_id  \
# 0            2278392      8222157  Female   [0-10)      ?                  6
# 1             149190     55629189  Female  [10-20)      ?                  1
# 2              64410     86047875  Female  [20-30)      ?                  1
# 3             500364     82442376    Male  [30-40)      ?                  1
# 4              16680     42519267    Male  [40-50)      ?                  1
# ...              ...          ...     ...      ...    ...                ...
# 101761     443847548    100162476    Male  [70-80)      ?                  1
# 101762     443847782     74694222  Female  [80-90)      ?                  1
# 101763     443854148     41088789    Male  [70-80)      ?                  1
# 101764     443857166     31693671  Female  [80-90)      ?                  2
# 101765     443867222    175429310    Male  [70-80)      ?                  1
#
# ...

# %%
#taking care of missing data
data1.isnull().any()
# Out:
# encounter_id                False
# patient_nbr                 False
# gender                      False
# age                         False
# weight                      False
# admission_type_id           False
# discharge_disposition_id    False
# admission_source_id         False
# time_in_hospital            False
# payer_code                  False
# medical_specialty           False
# num_lab_procedures          False
# num_procedures              False
# num_medications             False
# number_outpatient           False
# number_emergency            False
# number_inpatient            False
# diag_1                      False
# diag_2                      False
# diag_3                      False
# number_diagnoses            False
# max_glu_serum               False
# A1Cresult                   False
# metformin                   False
# repaglinide                 False
# nateglinide                 False
# chlorpropamide              False
# ...

# %% [markdown]
# # Label Encoding

# %%
from sklearn.preprocessing import LabelEncoder
lm=LabelEncoder()
data1['diabetesMed']=lm.fit_transform(data1['diabetesMed'])

# %%
data1
# Out:
#         patient_nbr             race  gender      age  admission_type_id  \
# 0           8222157        Caucasian  Female   [0-10)                  6
# 1          55629189        Caucasian  Female  [10-20)                  1
# 2          86047875  AfricanAmerican  Female  [20-30)                  1
# 3          82442376        Caucasian    Male  [30-40)                  1
# 4          42519267        Caucasian    Male  [40-50)                  1
# ...             ...              ...     ...      ...                ...
# 101761    100162476  AfricanAmerican    Male  [70-80)                  1
# 101762     74694222  AfricanAmerican  Female  [80-90)                  1
# 101763     41088789        Caucasian    Male  [70-80)                  1
# 101764     31693671        Caucasian  Female  [80-90)                  2
# 101765    175429310        Caucasian    Male  [70-80)                  1
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lm=LabelEncoder()
data1['change']=lm.fit_transform(data1['change'])

# %%
data1
# Out:
#         patient_nbr             race  gender      age  admission_type_id  \
# 0           8222157        Caucasian  Female   [0-10)                  6
# 1          55629189        Caucasian  Female  [10-20)                  1
# 2          86047875  AfricanAmerican  Female  [20-30)                  1
# 3          82442376        Caucasian    Male  [30-40)                  1
# 4          42519267        Caucasian    Male  [40-50)                  1
# ...             ...              ...     ...      ...                ...
# 101761    100162476  AfricanAmerican    Male  [70-80)                  1
# 101762     74694222  AfricanAmerican  Female  [80-90)                  1
# 101763     41088789        Caucasian    Male  [70-80)                  1
# 101764     31693671        Caucasian  Female  [80-90)                  2
# 101765    175429310        Caucasian    Male  [70-80)                  1
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lm=LabelEncoder()
data1['metformin-pioglitazone']=lm.fit_transform(data1['metformin-pioglitazone'])

# %%
data1
# Out:
#         patient_nbr             race  gender      age  admission_type_id  \
# 0           8222157        Caucasian  Female   [0-10)                  6
# 1          55629189        Caucasian  Female  [10-20)                  1
# 2          86047875  AfricanAmerican  Female  [20-30)                  1
# 3          82442376        Caucasian    Male  [30-40)                  1
# 4          42519267        Caucasian    Male  [40-50)                  1
# ...             ...              ...     ...      ...                ...
# 101761    100162476  AfricanAmerican    Male  [70-80)                  1
# 101762     74694222  AfricanAmerican  Female  [80-90)                  1
# 101763     41088789        Caucasian    Male  [70-80)                  1
# 101764     31693671        Caucasian  Female  [80-90)                  2
# 101765    175429310        Caucasian    Male  [70-80)                  1
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lm=LabelEncoder()
data1['metformin-rosiglitazone']=lm.fit_transform(data1['metformin-rosiglitazone'])

# %%
data1
# Out:
#         patient_nbr             race  gender      age  admission_type_id  \
# 0           8222157        Caucasian  Female   [0-10)                  6
# 1          55629189        Caucasian  Female  [10-20)                  1
# 2          86047875  AfricanAmerican  Female  [20-30)                  1
# 3          82442376        Caucasian    Male  [30-40)                  1
# 4          42519267        Caucasian    Male  [40-50)                  1
# ...             ...              ...     ...      ...                ...
# 101761    100162476  AfricanAmerican    Male  [70-80)                  1
# 101762     74694222  AfricanAmerican  Female  [80-90)                  1
# 101763     41088789        Caucasian    Male  [70-80)                  1
# 101764     31693671        Caucasian  Female  [80-90)                  2
# 101765    175429310        Caucasian    Male  [70-80)                  1
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lm=LabelEncoder()
data1['glimepiride-pioglitazone']=lm.fit_transform(data1['glimepiride-pioglitazone'])

# %%
data1
# Out:
#         patient_nbr             race  gender      age  admission_type_id  \
# 0           8222157        Caucasian  Female   [0-10)                  6
# 1          55629189        Caucasian  Female  [10-20)                  1
# 2          86047875  AfricanAmerican  Female  [20-30)                  1
# 3          82442376        Caucasian    Male  [30-40)                  1
# 4          42519267        Caucasian    Male  [40-50)                  1
# ...             ...              ...     ...      ...                ...
# 101761    100162476  AfricanAmerican    Male  [70-80)                  1
# 101762     74694222  AfricanAmerican  Female  [80-90)                  1
# 101763     41088789        Caucasian    Male  [70-80)                  1
# 101764     31693671        Caucasian  Female  [80-90)                  2
# 101765    175429310        Caucasian    Male  [70-80)                  1
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lm=LabelEncoder()
data1['glipizide-metformin']=lm.fit_transform(data1['glipizide-metformin'])

# %%
data1
# Out:
#         patient_nbr             race  gender      age  admission_type_id  \
# 0           8222157        Caucasian  Female   [0-10)                  6
# 1          55629189        Caucasian  Female  [10-20)                  1
# 2          86047875  AfricanAmerican  Female  [20-30)                  1
# 3          82442376        Caucasian    Male  [30-40)                  1
# 4          42519267        Caucasian    Male  [40-50)                  1
# ...             ...              ...     ...      ...                ...
# 101761    100162476  AfricanAmerican    Male  [70-80)                  1
# 101762     74694222  AfricanAmerican  Female  [80-90)                  1
# 101763     41088789        Caucasian    Male  [70-80)                  1
# 101764     31693671        Caucasian  Female  [80-90)                  2
# 101765    175429310        Caucasian    Male  [70-80)                  1
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lm=LabelEncoder()
data1['glyburide-metformin']=lm.fit_transform(data1['glyburide-metformin'])

# %%
data1
# Out:
#         patient_nbr             race  gender      age  admission_type_id  \
# 0           8222157        Caucasian  Female   [0-10)                  6
# 1          55629189        Caucasian  Female  [10-20)                  1
# 2          86047875  AfricanAmerican  Female  [20-30)                  1
# 3          82442376        Caucasian    Male  [30-40)                  1
# 4          42519267        Caucasian    Male  [40-50)                  1
# ...             ...              ...     ...      ...                ...
# 101761    100162476  AfricanAmerican    Male  [70-80)                  1
# 101762     74694222  AfricanAmerican  Female  [80-90)                  1
# 101763     41088789        Caucasian    Male  [70-80)                  1
# 101764     31693671        Caucasian  Female  [80-90)                  2
# 101765    175429310        Caucasian    Male  [70-80)                  1
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lm=LabelEncoder()
data1['gender']=lm.fit_transform(data1['gender'])

# %%
data1
# Out:
#         patient_nbr             race  gender      age  admission_type_id  \
# 0           8222157        Caucasian       0   [0-10)                  6
# 1          55629189        Caucasian       0  [10-20)                  1
# 2          86047875  AfricanAmerican       0  [20-30)                  1
# 3          82442376        Caucasian       1  [30-40)                  1
# 4          42519267        Caucasian       1  [40-50)                  1
# ...             ...              ...     ...      ...                ...
# 101761    100162476  AfricanAmerican       1  [70-80)                  1
# 101762     74694222  AfricanAmerican       0  [80-90)                  1
# 101763     41088789        Caucasian       1  [70-80)                  1
# 101764     31693671        Caucasian       0  [80-90)                  2
# 101765    175429310        Caucasian       1  [70-80)                  1
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lm=LabelEncoder()
data1['citoglipton']=lm.fit_transform(data1['citoglipton'])

# %%
data1
# Out:
#         patient_nbr             race  gender      age  admission_type_id  \
# 0           8222157        Caucasian       0   [0-10)                  6
# 1          55629189        Caucasian       0  [10-20)                  1
# 2          86047875  AfricanAmerican       0  [20-30)                  1
# 3          82442376        Caucasian       1  [30-40)                  1
# 4          42519267        Caucasian       1  [40-50)                  1
# ...             ...              ...     ...      ...                ...
# 101761    100162476  AfricanAmerican       1  [70-80)                  1
# 101762     74694222  AfricanAmerican       0  [80-90)                  1
# 101763     41088789        Caucasian       1  [70-80)                  1
# 101764     31693671        Caucasian       0  [80-90)                  2
# 101765    175429310        Caucasian       1  [70-80)                  1
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lm=LabelEncoder()
data1['diabetesMed']=lm.fit_transform(data1['diabetesMed'])

# %%
data1
# Out:
#         encounter_id  patient_nbr             race  gender      age  \
# 1             149190     55629189        Caucasian  Female  [10-20)
# 2              64410     86047875  AfricanAmerican  Female  [20-30)
# 3             500364     82442376        Caucasian    Male  [30-40)
# 4              16680     42519267        Caucasian    Male  [40-50)
# 5              35754     82637451        Caucasian    Male  [50-60)
# ...              ...          ...              ...     ...      ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)
# 101763     443854148     41088789        Caucasian    Male  [70-80)
# 101764     443857166     31693671        Caucasian  Female  [80-90)
# 101765     443867222    175429310        Caucasian    Male  [70-80)
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 1                       1                         1                    7
# ...

# %%
from sklearn.preprocessing import LabelEncoder
lm=LabelEncoder()
data1['gender']=lm.fit_transform(data1['gender'])
data1
# Out:
#         encounter_id  patient_nbr             race  gender      age  \
# 1             149190     55629189        Caucasian       0  [10-20)
# 2              64410     86047875  AfricanAmerican       0  [20-30)
# 3             500364     82442376        Caucasian       1  [30-40)
# 4              16680     42519267        Caucasian       1  [40-50)
# 5              35754     82637451        Caucasian       1  [50-60)
# ...              ...          ...              ...     ...      ...
# 101761     443847548    100162476  AfricanAmerican       1  [70-80)
# 101762     443847782     74694222  AfricanAmerican       0  [80-90)
# 101763     443854148     41088789        Caucasian       1  [70-80)
# 101764     443857166     31693671        Caucasian       0  [80-90)
# 101765     443867222    175429310        Caucasian       1  [70-80)
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 1                       1                         1                    7
# ...

# %%
data1['service_utilization'] = data1['number_outpatient'] + data1['number_emergency'] + data1['number_inpatient']

# %%
data1
# Out:
#         encounter_id  patient_nbr             race  gender      age  \
# 1             149190     55629189        Caucasian       0  [10-20)
# 2              64410     86047875  AfricanAmerican       0  [20-30)
# 3             500364     82442376        Caucasian       1  [30-40)
# 4              16680     42519267        Caucasian       1  [40-50)
# 5              35754     82637451        Caucasian       1  [50-60)
# ...              ...          ...              ...     ...      ...
# 101761     443847548    100162476  AfricanAmerican       1  [70-80)
# 101762     443847782     74694222  AfricanAmerican       0  [80-90)
# 101763     443854148     41088789        Caucasian       1  [70-80)
# 101764     443857166     31693671        Caucasian       0  [80-90)
# 101765     443867222    175429310        Caucasian       1  [70-80)
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 1                       1                         1                    7
# ...

# %%
keys = ['metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'glipizide', 'glyburide', 'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'insulin', 'glyburide-metformin', 'tolazamide', 'metformin-pioglitazone','metformin-rosiglitazone', 'glimepiride-pioglitazone', 'glipizide-metformin', 'troglitazone', 'tolbutamide', 'acetohexamide']
for col in keys:
    colname = str(col) + 'temp'
    data1[colname] = data1[col].apply(lambda x: 0 if (x == 'No' or x == 'Steady') else 1)
data1['numchange'] = 0
for col in keys:
    colname = str(col) + 'temp'
    data1['numchange'] = data1['numchange'] + data1[colname]
    del data1[colname]
    
data1['numchange'].value_counts()
# Out:
# 0    70142
# 1    24922
# 2     1271
# 3      106
# 4        5
# Name: numchange, dtype: int64

# %%
data1['change'] = data1['change'].replace('Ch', 1)
data1['change'] = data1['change'].replace('No', 0)
data1['gender'] = data1['gender'].replace('Male', 1)
data1['gender'] = data1['gender'].replace('Female', 0)
data1['diabetesMed'] = data1['diabetesMed'].replace('Yes', 1)
data1['diabetesMed'] = data1['diabetesMed'].replace('No', 0)
# keys is the same as before
for col in keys:
    data1[col] = data1[col].replace('No', 0)
    data1[col] = data1[col].replace('Steady', 1)
    data1[col] = data1[col].replace('Up', 1)
    data1[col] = data1[col].replace('Down', 1)

# %%
data1
# Out:
#         encounter_id  patient_nbr             race  gender      age  \
# 1             149190     55629189        Caucasian       0  [10-20)
# 2              64410     86047875  AfricanAmerican       0  [20-30)
# 3             500364     82442376        Caucasian       1  [30-40)
# 4              16680     42519267        Caucasian       1  [40-50)
# 5              35754     82637451        Caucasian       1  [50-60)
# ...              ...          ...              ...     ...      ...
# 101761     443847548    100162476  AfricanAmerican       1  [70-80)
# 101762     443847782     74694222  AfricanAmerican       0  [80-90)
# 101763     443854148     41088789        Caucasian       1  [70-80)
# 101764     443857166     31693671        Caucasian       0  [80-90)
# 101765     443867222    175429310        Caucasian       1  [70-80)
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 1                       1                         1                    7
# ...

# %%
data1['A1Cresult'] = data1['A1Cresult'].replace('>7', 1)
data1['A1Cresult'] = data1['A1Cresult'].replace('>8', 1)
data1['A1Cresult'] = data1['A1Cresult'].replace('Norm', 0)
data1['A1Cresult'] = data1['A1Cresult'].replace('None', -99)
data1['max_glu_serum'] = data1['max_glu_serum'].replace('>200', 1)
data1['max_glu_serum'] = data1['max_glu_serum'].replace('>300', 1)
data1['max_glu_serum'] = data1['max_glu_serum'].replace('Norm', 0)
data1['max_glu_serum'] = data1['max_glu_serum'].replace('None', -99)

# %%
data1
# Out:
#         encounter_id  patient_nbr             race  gender      age  \
# 1             149190     55629189        Caucasian       0  [10-20)
# 2              64410     86047875  AfricanAmerican       0  [20-30)
# 3             500364     82442376        Caucasian       1  [30-40)
# 4              16680     42519267        Caucasian       1  [40-50)
# 5              35754     82637451        Caucasian       1  [50-60)
# ...              ...          ...              ...     ...      ...
# 101761     443847548    100162476  AfricanAmerican       1  [70-80)
# 101762     443847782     74694222  AfricanAmerican       0  [80-90)
# 101763     443854148     41088789        Caucasian       1  [70-80)
# 101764     443857166     31693671        Caucasian       0  [80-90)
# 101765     443867222    175429310        Caucasian       1  [70-80)
#
#         admission_type_id  discharge_disposition_id  admission_source_id  \
# 1                       1                         1                    7
# ...

# %%
for i in range(0,10):
    data1['age'] = data1['age'].replace('['+str(10*i)+'-'+str(10*(i+1))+')', i+1)
data1['age'].value_counts()
# Out:
# 8     24815
# 7     21521
# 6     16546
# 9     16223
# 5      9208
# 4      3538
# 10     2594
# 3      1471
# 2       466
# 1        64
# Name: age, dtype: int64

# %%
data1 = data1.drop_duplicates(subset= ['patient_nbr'], keep = 'first')
data1.shape
(70442, 55)
# Out:
# (70442, 55)

# %%
data1=data1.drop(['citoglipton','examide'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-9088e9f4dc79> in <module>
# ----> 1 data1=data1.drop(['citoglipton','examide'],axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
# ...

# %%
data1.head().T
# Out:
#                                   1                2          3          4  \
# encounter_id                 149190            64410     500364      16680
# patient_nbr                55629189         86047875   82442376   42519267
# race                      Caucasian  AfricanAmerican  Caucasian  Caucasian
# gender                            0                0          1          1
# age                               2                3          4          5
# admission_type_id                 1                1          1          1
# discharge_disposition_id          1                1          1          1
# admission_source_id               7                7          7          7
# time_in_hospital                  3                2          2          1
# num_lab_procedures               59               11         44         51
# num_procedures                    0                5          1          0
# ...

# %%
data1['readmitted'].value_counts()
# Out:
# NO     39826
# >30    21625
# <30     6129
# Name: readmitted, dtype: int64

# %%
data1['readmitted'] = data1['readmitted'].replace('>30', 0)
data1['readmitted'] = data1['readmitted'].replace('<30', 1)
data1['readmitted'] = data1['readmitted'].replace('NO', 0)

# %%
data1['level1_diag1'] = data1['diag_1']
data1['level2_diag1'] = data1['diag_1']
data1['level1_diag2'] = data1['diag_2']
data1['level2_diag2'] = data1['diag_2']
data1['level1_diag3'] = data1['diag_3']
data1['level2_diag3'] = data1['diag_3']

# %%
data1['level1_diag1'] = data1['diag_1']
data1['level2_diag1'] = data1['diag_1']
data1['level1_diag2'] = data1['diag_2']
data1['level2_diag2'] = data1['diag_2']
data1['level1_diag3'] = data1['diag_3']
data1['level2_diag3'] = data1 ['diag_3']

# %%
data1.loc[data1['diag_1'].str.contains('V'), ['level1_diag1', 'level2_diag1']] = 0
data1.loc[data1['diag_1'].str.contains('E'), ['level1_diag1', 'level2_diag1']] = 0
data1.loc[data1['diag_2'].str.contains('V'), ['level1_diag2', 'level2_diag2']] = 0
data1.loc[data1['diag_2'].str.contains('E'), ['level1_diag2', 'level2_diag2']] = 0
data1.loc[data1['diag_3'].str.contains('V'), ['level1_diag3', 'level2_diag3']] = 0
data1.loc[data1['diag_3'].str.contains('E'), ['level1_diag3', 'level2_diag3']] = 0
data1['level1_diag1'] = data1['level1_diag1'].replace('?', -1)
data1['level2_diag1'] = data1['level2_diag1'].replace('?', -1)
data1['level1_diag2'] = data1['level1_diag2'].replace('?', -1)
data1['level2_diag2'] = data1['level2_diag2'].replace('?', -1)
data1['level1_diag3'] = data1['level1_diag3'].replace('?', -1)
data1['level2_diag3'] = data1['level2_diag3'].replace('?', -1)

# %%
data1['level1_diag1'] = data1['level1_diag1'].astype(float)
data1['level2_diag1'] = data1['level2_diag1'].astype(float)
data1['level1_diag2'] = data1['level1_diag2'].astype(float)
data1['level2_diag2'] = data1['level2_diag2'].astype(float)
data1['level1_diag3'] = data1['level1_diag3'].astype(float)
data1['level2_diag3'] = data1['level2_diag3'].astype(float)

# %%
for index, row in data1.iterrows():
    if (row['level1_diag1'] >= 390 and row['level1_diag1'] < 460) or (np.floor(row['level1_diag1']) == 785):
        data1.loc[index, 'level1_diag1'] = 1
    elif (row['level1_diag1'] >= 460 and row['level1_diag1'] < 520) or (np.floor(row['level1_diag1']) == 786):
        data1.loc[index, 'level1_diag1'] = 2
    elif (row['level1_diag1'] >= 520 and row['level1_diag1'] < 580) or (np.floor(row['level1_diag1']) == 787):
        data1.loc[index, 'level1_diag1'] = 3
    elif (np.floor(row['level1_diag1']) == 250):
        data1.loc[index, 'level1_diag1'] = 4
    elif (row['level1_diag1'] >= 800 and row['level1_diag1'] < 1000):
        data1.loc[index, 'level1_diag1'] = 5
    elif (row['level1_diag1'] >= 710 and row['level1_diag1'] < 740):
        data1.loc[index, 'level1_diag1'] = 6
    elif (row['level1_diag1'] >= 580 and row['level1_diag1'] < 630) or (np.floor(row['level1_diag1']) == 788):
        data1.loc[index, 'level1_diag1'] = 7
    elif (row['level1_diag1'] >= 140 and row['level1_diag1'] < 240):
        data1.loc[index, 'level1_diag1'] = 8
    else:
        data1.loc[index, 'level1_diag1'] = 0
        
    if (row['level1_diag2'] >= 390 and row['level1_diag2'] < 460) or (np.floor(row['level1_diag2']) == 785):
        data1.loc[index, 'level1_diag2'] = 1
    elif (row['level1_diag2'] >= 460 and row['level1_diag2'] < 520) or (np.floor(row['level1_diag2']) == 786):
        data1.loc[index, 'level1_diag2'] = 2
    elif (row['level1_diag2'] >= 520 and row['level1_diag2'] < 580) or (np.floor(row['level1_diag2']) == 787):
        data1.loc[index, 'level1_diag2'] = 3
    elif (np.floor(row['level1_diag2']) == 250):
        data1.loc[index, 'level1_diag2'] = 4
    elif (row['level1_diag2'] >= 800 and row['level1_diag2'] < 1000):
        data1.loc[index, 'level1_diag2'] = 5
    elif (row['level1_diag2'] >= 710 and row['level1_diag2'] < 740):
        data1.loc[index, 'level1_diag2'] = 6
    elif (row['level1_diag2'] >= 580 and row['level1_diag2'] < 630) or (np.floor(row['level1_diag2']) == 788):
        data1.loc[index, 'level1_diag2'] = 7
    elif (row['level1_diag2'] >= 140 and row['level1_diag2'] < 240):
        data1.loc[index, 'level1_diag2'] = 8
    else:
        data1.loc[index, 'level1_diag2'] = 0
    
    if (row['level1_diag3'] >= 390 and row['level1_diag3'] < 460) or (np.floor(row['level1_diag3']) == 785):
        data1.loc[index, 'level1_diag3'] = 1
    elif (row['level1_diag3'] >= 460 and row['level1_diag3'] < 520) or (np.floor(row['level1_diag3']) == 786):
        data1.loc[index, 'level1_diag3'] = 2
    elif (row['level1_diag3'] >= 520 and row['level1_diag3'] < 580) or (np.floor(row['level1_diag3']) == 787):
        data1.loc[index, 'level1_diag3'] = 3
    elif (np.floor(row['level1_diag3']) == 250):
        data1.loc[index, 'level1_diag3'] = 4
    elif (row['level1_diag3'] >= 800 and row['level1_diag3'] < 1000):
        data1.loc[index, 'level1_diag3'] = 5
    elif (row['level1_diag3'] >= 710 and row['level1_diag3'] < 740):
        data1.loc[index, 'level1_diag3'] = 6
    elif (row['level1_diag3'] >= 580 and row['level1_diag3'] < 630) or (np.floor(row['level1_diag3']) == 788):
        data1.loc[index, 'level1_diag3'] = 7
    elif (row['level1_diag3'] >= 140 and row['level1_diag3'] < 240):
        data1.loc[index, 'level1_diag3'] = 8
    else:
        data1.loc[index, 'level1_diag3'] = 0

# %%
for index, row in data1.iterrows():
    if (row['level2_diag1'] >= 390 and row['level2_diag1'] < 399):
        data1.loc[index, 'level2_diag1'] = 1
    elif (row['level2_diag1'] >= 401 and row['level2_diag1'] < 415):
        data1.loc[index, 'level2_diag1'] = 2
    elif (row['level2_diag1'] >= 415 and row['level2_diag1'] < 460):
        data1.loc[index, 'level2_diag1'] = 3
    elif (np.floor(row['level2_diag1']) == 785):
        data1.loc[index, 'level2_diag1'] = 4
    elif (row['level2_diag1'] >= 460 and row['level2_diag1'] < 489):
        data1.loc[index, 'level2_diag1'] = 5
    elif (row['level2_diag1'] >= 490 and row['level2_diag1'] < 497):
        data1.loc[index, 'level2_diag1'] = 6
    elif (row['level2_diag1'] >= 500 and row['level2_diag1'] < 520):
        data1.loc[index, 'level2_diag1'] = 7
    elif (np.floor(row['level2_diag1']) == 786):
        data1.loc[index, 'level2_diag1'] = 8
    elif (row['level2_diag1'] >= 520 and row['level2_diag1'] < 530):
        data1.loc[index, 'level2_diag1'] = 9
    elif (row['level2_diag1'] >= 530 and row['level2_diag1'] < 544):
        data1.loc[index, 'level2_diag1'] = 10
    elif (row['level2_diag1'] >= 550 and row['level2_diag1'] < 554):
        data1.loc[index, 'level2_diag1'] = 11
    elif (row['level2_diag1'] >= 555 and row['level2_diag1'] < 580):
        data1.loc[index, 'level2_diag1'] = 12
    elif (np.floor(row['level2_diag1']) == 787):
        data1.loc[index, 'level2_diag1'] = 13
    elif (np.floor(row['level2_diag1']) == 250):
        data1.loc[index, 'level2_diag1'] = 14
    elif (row['level2_diag1'] >= 800 and row['level2_diag1'] < 1000):
        data1.loc[index, 'level2_diag1'] = 15
    elif (row['level2_diag1'] >= 710 and row['level2_diag1'] < 740):
        data1.loc[index, 'level2_diag1'] = 16
    elif (row['level2_diag1'] >= 580 and row['level2_diag1'] < 630):
        data1.loc[index, 'level2_diag1'] = 17
    elif (np.floor(row['level2_diag1']) == 788):
        data1.loc[index, 'level2_diag1'] = 18
    elif (row['level2_diag1'] >= 140 and row['level2_diag1'] < 240):
        data1.loc[index, 'level2_diag1'] = 19
    elif row['level2_diag1'] >= 240 and row['level2_diag1'] < 280 and (np.floor(row['level2_diag1']) != 250):
        data1.loc[index, 'level2_diag1'] = 20
    elif (row['level2_diag1'] >= 680 and row['level2_diag1'] < 710) or (np.floor(row['level2_diag1']) == 782):
        data1.loc[index, 'level2_diag1'] = 21
    elif (row['level2_diag1'] >= 290 and row['level2_diag1'] < 320):
        data1.loc[index, 'level2_diag1'] = 22
    else:
        data1.loc[index, 'level2_diag1'] = 0
        
    if (row['level2_diag2'] >= 390 and row['level2_diag2'] < 399):
        data1.loc[index, 'level2_diag2'] = 1
    elif (row['level2_diag2'] >= 401 and row['level2_diag2'] < 415):
        data1.loc[index, 'level2_diag2'] = 2
    elif (row['level2_diag2'] >= 415 and row['level2_diag2'] < 460):
        data1.loc[index, 'level2_diag2'] = 3
    elif (np.floor(row['level2_diag2']) == 785):
        data1.loc[index, 'level2_diag2'] = 4
    elif (row['level2_diag2'] >= 460 and row['level2_diag2'] < 489):
        data1.loc[index, 'level2_diag2'] = 5
    elif (row['level2_diag2'] >= 490 and row['level2_diag2'] < 497):
        data1.loc[index, 'level2_diag2'] = 6
    elif (row['level2_diag2'] >= 500 and row['level2_diag2'] < 520):
        data1 .loc[index, 'level2_diag2'] = 7
    elif (np.floor(row['level2_diag2']) == 786):
        data1.loc[index, 'level2_diag2'] = 8
    elif (row['level2_diag2'] >= 520 and row['level2_diag2'] < 530):
        data1.loc[index, 'level2_diag2'] = 9
    elif (row['level2_diag2'] >= 530 and row['level2_diag2'] < 544):
        data1.loc[index, 'level2_diag2'] = 10
    elif (row['level2_diag2'] >= 550 and row['level2_diag2'] < 554):
        data1.loc[index, 'level2_diag2'] = 11
    elif (row['level2_diag2'] >= 555 and row['level2_diag2'] < 580):
        data1.loc[index, 'level2_diag2'] = 12
    elif (np.floor(row['level2_diag2']) == 787):
        data1.loc[index, 'level2_diag2'] = 13
    elif (np.floor(row['level2_diag2']) == 250):
        data1.loc[index, 'level2_diag2'] = 14
    elif (row['level2_diag2'] >= 800 and row['level2_diag2'] < 1000):
        data1.loc[index, 'level2_diag2'] = 15
    elif (row['level2_diag2'] >= 710 and row['level2_diag2'] < 740):
        data1.loc[index, 'level2_diag2'] = 16
    elif (row['level2_diag2'] >= 580 and row['level2_diag2'] < 630):
        data1.loc[index, 'level2_diag2'] = 17
    elif (np.floor(row['level2_diag2']) == 788):
        data1.loc[index, 'level2_diag2'] = 18
    elif (row['level2_diag2'] >= 140 and row['level2_diag2'] < 240):
        data1.loc[index, 'level2_diag2'] = 19
    elif row['level2_diag2'] >= 240 and row['level2_diag2'] < 280 and (np.floor(row['level2_diag2']) != 250):
        data1.loc[index, 'level2_diag2'] = 20
    elif (row['level2_diag2'] >= 680 and row['level2_diag2'] < 710) or (np.floor(row['level2_diag2']) == 782):
        data1.loc[index, 'level2_diag2'] = 21
    elif (row['level2_diag2'] >= 290 and row['level2_diag2'] < 320):
        data1.loc[index, 'level2_diag2'] = 22
    else:
        data1.loc[index, 'level2_diag2'] = 0
        
        
    if (row['level2_diag3'] >= 390 and row['level2_diag3'] < 399):
        data1.loc[index, 'level2_diag3'] = 1
    elif (row['level2_diag3'] >= 401 and row['level2_diag3'] < 415):
        data1.loc[index, 'level2_diag3'] = 2
    elif (row['level2_diag3'] >= 415 and row['level2_diag3'] < 460):
        data1.loc[index, 'level2_diag3'] = 3
    elif (np.floor(row['level2_diag3']) == 785):
        data1.loc[index, 'level2_diag3'] = 4
    elif (row['level2_diag3'] >= 460 and row['level2_diag3'] < 489):
        data1.loc[index, 'level2_diag3'] = 5
    elif (row['level2_diag3'] >= 490 and row['level2_diag3'] < 497):
        data1.loc[index, 'level2_diag3'] = 6
    elif (row['level2_diag3'] >= 500 and row['level2_diag3'] < 520):
        data1.loc[index, 'level2_diag3'] = 7
    elif (np.floor(row['level2_diag3']) == 786):
        data1.loc[index, 'level2_diag3'] = 8
    elif (row['level2_diag3'] >= 520 and row['level2_diag3'] < 530):
        data1.loc[index, 'level2_diag3'] = 9
    elif (row['level2_diag3'] >= 530 and row['level2_diag3'] < 544):
        data1.loc[index, 'level2_diag3'] = 10
    elif (row['level2_diag3'] >= 550 and row['level2_diag3'] < 554):
        data1.loc[index, 'level2_diag3'] = 11
    elif (row['level2_diag3'] >= 555 and row['level2_diag3'] < 580):
        data1.loc[index, 'level2_diag3'] = 12
    elif (np.floor(row['level2_diag3']) == 787):
        data1.loc[index, 'level2_diag3'] = 13
    elif (np.floor(row['level2_diag3']) == 250):
        data1.loc[index, 'level2_diag3'] = 14
    elif (row['level2_diag3'] >= 800 and row['level2_diag3'] < 1000):
        data1.loc[index, 'level2_diag3'] = 15
    elif (row['level2_diag3'] >= 710 and row['level2_diag3'] < 740):
        data1.loc[index, 'level2_diag3'] = 16
    elif (row['level2_diag3'] >= 580 and row['level2_diag3'] < 630):
        data1.loc[index, 'level2_diag3'] = 17
    elif (np.floor(row['level2_diag3']) == 788):
        data1.loc[index, 'level2_diag3'] = 18
    elif (row['level2_diag3'] >= 140 and row['level2_diag3'] < 240):
        data1.loc[index, 'level2_diag3'] = 19
    elif row['level2_diag3'] >= 240 and row['level2_diag3'] < 280 and (np.floor(row['level2_diag3']) != 250):
        data1.loc[index, 'level2_diag3'] = 20
    elif (row['level2_diag3'] >= 680 and row['level2_diag3'] < 710) or (np.floor(row['level2_diag3']) == 782):
        data1.loc[index, 'level2_diag3'] = 21
    elif (row['level2_diag3'] >= 290 and row['level2_diag3'] < 320):
        data1.loc[index, 'level2_diag3'] = 22
    else:
        data1.loc[index, 'level2_diag3'] = 0

# %%
data1['age'] = data1['age'].astype('int64')
print(data1.age.value_counts())
# convert age categories to mid-point values
age_dict = {1:5, 2:15, 3:25, 4:35, 5:45, 6:55, 7:65, 8:75, 9:85, 10:95}
data1['age'] = data1.age.map(age_dict)
print(data1.age.value_counts())
# Out:
# 8     17331
# 7     15228
# 6     11903
# 9     10931
# 5      6494
# 4      2519
# 10     1750
# 3      1004
# 2       357
# 1        63
# Name: age, dtype: int64
# 75    17331
# 65    15228
# 55    11903
# 85    10931
# 45     6494
# 35     2519
# 95     1750
# 25     1004
# 15      357
# 5        63
# Name: age, dtype: int64

# %%
i = ['encounter_id', 'patient_nbr', 'gender', 'admission_type_id', 'discharge_disposition_id', 'admission_source_id',\
          'A1Cresult', 'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'acetohexamide', \
          'glipizide', 'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose','miglitol', \
          'troglitazone', 'tolazamide', 'insulin', 'glyburide-metformin', 'glipizide-metformin', \
          'glimepiride-pioglitazone', 'metformin-rosiglitazone', 'metformin-pioglitazone', 'change', 'diabetesMed', \
          'age', 'A1Cresult', 'max_glu_serum', 'level1_diag1', 'level1_diag2', 'level1_diag3', 'level2_diag1', 'level2_diag2', 'level2_diag3']

data1[i] = data1[i].astype('object')

# %%
data1.dtypes
# Out:
# encounter_id                object
# patient_nbr                 object
# race                        object
# gender                      object
# age                         object
# admission_type_id           object
# discharge_disposition_id    object
# admission_source_id         object
# time_in_hospital             int64
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# chlorpropamide              object
# glimepiride                 object
# acetohexamide               object
# ...

# %%
data1['nummed'] = 0

for col in keys:
    data1['nummed'] = data1['nummed'] + data1[col]
data1['nummed'].value_counts()
# Out:
# 1    29975
# 0    16267
# 2    14865
# 3     5444
# 4      976
# 5       49
# 6        4
# Name: nummed, dtype: int64

# %%
num_col = list(set(list(data1._get_numeric_data().columns))- {'readmitted'})
num_col
# Out:
# ['num_procedures',
#  'service_utilization',
#  'number_emergency',
#  'numchange',
#  'number_diagnoses',
#  'number_outpatient',
#  'num_medications',
#  'time_in_hospital',
#  'number_inpatient',
#  'num_lab_procedures']

# %%
statdataframe = pd.DataFrame()
statdataframe['numeric_column'] = num_col
skew_before = []
skew_after = []

kurt_before = []
kurt_after = []

standard_deviation_before = []
standard_deviation_after = []

log_transform_needed = []

log_type = []

for i in num_col:
    skewval = data1[i].skew()
    skew_before.append(skewval)
    
    kurtval = data1[i].kurtosis()
    kurt_before.append(kurtval)
    
    sdval = data1[i].std()
    standard_deviation_before.append(sdval)
    
    if (abs(skewval) >2) & (abs(kurtval) >2):
        log_transform_needed.append('Yes')
        
        if len(data1[data1[i] == 0])/len(data1) <=0.02:
            log_type.append('log')
            skewvalnew = np.log(pd.DataFrame(data1[train_data[i] > 0])[i]).skew()
            skew_after.append(skewvalnew)
            
            kurtvalnew = np.log(pd.DataFrame(data1[train_data[i] > 0])[i]).kurtosis()
            kurt_after.append(kurtvalnew)
            
            sdvalnew = np.log(pd.DataFrame(data1[train_data[i] > 0])[i]).std()
            standard_deviation_after.append(sdvalnew)
            
        else:
            log_type.append('log1p')
            skewvalnew = np.log1p(pd.DataFrame(data1[data1[i] >= 0])[i]).skew()
            skew_after.append(skewvalnew)
        
            kurtvalnew = np.log1p(pd.DataFrame(data1[data1[i] >= 0])[i]).kurtosis()
            kurt_after.append(kurtvalnew)
            
            sdvalnew = np.log1p(pd.DataFrame(data1[data1[i] >= 0])[i]).std()
            standard_deviation_after.append(sdvalnew)
            
    else:
        log_type.append('NA')
        log_transform_needed.append('No')
        
        skew_after.append(skewval)
        kurt_after.append(kurtval)
        standard_deviation_after.append(sdval)

statdataframe['skew_before'] = skew_before
statdataframe['kurtosis_before'] = kurt_before
statdataframe['standard_deviation_before'] = standard_deviation_before
statdataframe['log_transform_needed'] = log_transform_needed
statdataframe['log_type'] = log_type
statdataframe['skew_after'] = skew_after
statdataframe['kurtosis_after'] = kurt_after
statdataframe['standard_deviation_after'] = standard_deviation_after

# %%
statdataframe
# Out:
#         numeric_column  skew_before  kurtosis_before  \
# 0       num_procedures     1.215816         0.532485
# 1  service_utilization     6.609926        95.765429
# 2     number_emergency    21.034445      1184.150024
# 3            numchange     1.606592         2.096947
# 4     number_diagnoses    -0.663394        -0.630912
# 5    number_outpatient     9.575296       179.972141
# 6      num_medications     1.441540         3.893419
# 7     time_in_hospital     1.161188         0.950786
# 8     number_inpatient     5.427730        44.468243
# 9   num_lab_procedures    -0.218584        -0.301873
#
#    standard_deviation_before log_transform_needed log_type  skew_after  \
# 0                   1.758365                   No       NA    1.215816
# 1                   1.449969                  Yes    log1p    1.867026
# 2                   0.518948                  Yes    log1p    4.198664
# 3                   0.476654                   No       NA    1.606592
# ...

# %%
for i in range(len(statdataframe)):
    if statdataframe['log_transform_needed'][i] == 'Yes':
        colname = str(statdataframe['numeric_column'][i])
        
        if statdataframe['log_type'][i] == 'log':
            data1 = data1[data1[colname] > 0]
            data1[colname + "_log"] = np.log(data1[colname])
            
        elif statdataframe['log_type'][i] == 'log1p':
            data1 = data1[data1[colname] >= 0]
            data1[colname + "_log1p"] = np.log1p(data1[colname])

# %%
data1 = data1.drop(['number_outpatient', 'number_inpatient', 'number_emergency','service_utilization'], axis = 1)

# %%
data1.shape
# Out:
# (67580, 54)

# %%
numerics = list(set(list(data1._get_numeric_data().columns))- {'readmitted'})
numerics
# Out:
# ['num_lab_procedures',
#  'number_emergency_log1p',
#  'num_procedures',
#  'number_outpatient_log1p',
#  'number_inpatient_log1p',
#  'numchange',
#  'num_medications',
#  'service_utilization_log1p',
#  'time_in_hospital',
#  'number_diagnoses']

# %%
data1.encounter_id = data1.encounter_id.astype('int64')
data1.patient_nbr = data1.patient_nbr.astype('int64')
data1.diabetesMed = data1.diabetesMed.astype('int64')
data1.change = data1.change.astype('int64')

# convert data type of nominal features in dataframe to 'object' type for aggregating
i = ['metformin', 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'acetohexamide', \
          'glipizide', 'glyburide', 'tolbutamide', 'pioglitazone', 'rosiglitazone', 'acarbose','miglitol', \
          'troglitazone', 'tolazamide', 'insulin', 'glyburide-metformin', 'glipizide-metformin', \
          'glimepiride-pioglitazone', 'metformin-rosiglitazone', 'metformin-pioglitazone','A1Cresult']
data1[i] = data1[i].astype('int64')

data1.dtypes
# Out:
# encounter_id                   int64
# patient_nbr                    int64
# race                          object
# gender                        object
# age                           object
# admission_type_id             object
# discharge_disposition_id      object
# admission_source_id           object
# time_in_hospital               int64
# num_lab_procedures             int64
# num_procedures                 int64
# num_medications                int64
# diag_1                        object
# diag_2                        object
# diag_3                        object
# number_diagnoses               int64
# max_glu_serum                 object
# A1Cresult                      int64
# metformin                      int64
# repaglinide                    int64
# nateglinide                    int64
# chlorpropamide                 int64
# glimepiride                    int64
# acetohexamide                  int64
# glipizide                      int64
# ...

# %%
data1copy = data1.copy(deep = True)

# %%
data1['readmitted'] = data1['readmitted'].apply(lambda x: 0 if x == 2 else x)

# %%
data1.drop(['diag_1', 'diag_2', 'diag_3', 'level2_diag1', 'level1_diag2', 'level2_diag2', 'level1_diag3',
         'level2_diag3'], axis=1, inplace=True)

# %%
interactionterms = [('num_medications','time_in_hospital'),
('num_medications','num_procedures'),
('time_in_hospital','num_lab_procedures'),
('num_medications','num_lab_procedures'),
('num_medications','number_diagnoses'),
('age','number_diagnoses'),
('change','num_medications'),
('number_diagnoses','time_in_hospital'),
('num_medications','numchange')]

# %%
for inter in interactionterms:
    name = inter[0] + '|' + inter[1]
    data1[name] = data1[inter[0]] * data1[inter[1]]

# %%
data1[['num_medications','time_in_hospital', 'num_medications|time_in_hospital']].head()
# Out:
#    num_medications  time_in_hospital  num_medications|time_in_hospital
# 1               18                 3                                54
# 2               13                 2                                26
# 3               16                 2                                32
# 4                8                 1                                 8
# 5               16                 3                                48

# %% [markdown]
# # One Hot Encoding

# %%
import os
os.getcwd()
os.chdir("C:\\Users\\SriKavyaChintalapudi\\Desktop\\remote internship 2020\\python code")
os.getcwd()
# Out:
# 'C:\\Users\\SriKavyaChintalapudi\\Desktop\\remote internship 2020\\python code'

# %%
import numpy as np
import pandas as pd

# %%
data1=pd.read_csv("readmission.csv")

# %%
data1
# Out:
#         encounter_id  patient_nbr  gender      age weight  admission_type_id  \
# 0            2278392      8222157  Female   [0-10)      ?                  6
# 1             149190     55629189  Female  [10-20)      ?                  1
# 2              64410     86047875  Female  [20-30)      ?                  1
# 3             500364     82442376    Male  [30-40)      ?                  1
# 4              16680     42519267    Male  [40-50)      ?                  1
# ...              ...          ...     ...      ...    ...                ...
# 101761     443847548    100162476    Male  [70-80)      ?                  1
# 101762     443847782     74694222  Female  [80-90)      ?                  1
# 101763     443854148     41088789    Male  [70-80)      ?                  1
# 101764     443857166     31693671  Female  [80-90)      ?                  2
# 101765     443867222    175429310    Male  [70-80)      ?                  1
#
# ...

# %%
data1
# Out:
#         encounter_id  patient_nbr  gender      age weight  admission_type_id  \
# 0            2278392      8222157  Female   [0-10)      ?                  6
# 1             149190     55629189  Female  [10-20)      ?                  1
# 2              64410     86047875  Female  [20-30)      ?                  1
# 3             500364     82442376    Male  [30-40)      ?                  1
# 4              16680     42519267    Male  [40-50)      ?                  1
# ...              ...          ...     ...      ...    ...                ...
# 101761     443847548    100162476    Male  [70-80)      ?                  1
# 101762     443847782     74694222  Female  [80-90)      ?                  1
# 101763     443854148     41088789    Male  [70-80)      ?                  1
# 101764     443857166     31693671  Female  [80-90)      ?                  2
# 101765     443867222    175429310    Male  [70-80)      ?                  1
#
# ...

# %%
data1.dtypes
# Out:
# encounter_id                 int64
# patient_nbr                  int64
# race                        object
# gender                      object
# age                         object
# weight                      object
# admission_type_id            int64
# discharge_disposition_id     int64
# admission_source_id          int64
# time_in_hospital             int64
# payer_code                  object
# medical_specialty           object
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# ...

# %%
data1.columns
# Out:
# Index(['encounter_id', 'patient_nbr', 'race', 'gender', 'age', 'weight',
#        'admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'time_in_hospital', 'payer_code', 'medical_specialty',
#        'num_lab_procedures', 'num_procedures', 'num_medications',
#        'number_outpatient', 'number_emergency', 'number_inpatient', 'diag_1',
#        'diag_2', 'diag_3', 'number_diagnoses', 'max_glu_serum', 'A1Cresult',
#        'metformin', 'repaglinide', 'nateglinide', 'chlorpropamide',
#        'glimepiride', 'acetohexamide', 'glipizide', 'glyburide', 'tolbutamide',
#        'pioglitazone', 'rosiglitazone', 'acarbose', 'miglitol', 'troglitazone',
#        'tolazamide', 'examide', 'citoglipton', 'insulin',
#        'glyburide-metformin', 'glipizide-metformin',
#        'glimepiride-pioglitazone', 'metformin-rosiglitazone',
#        'metformin-pioglitazone', 'change', 'diabetesMed', 'readmitted'],
#       dtype='object')

# %%
data1.describe()
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  1.017660e+05  1.017660e+05      101766.000000
# mean   1.652016e+08  5.433040e+07           2.024006
# std    1.026403e+08  3.869636e+07           1.445403
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    8.496119e+07  2.341322e+07           1.000000
# 50%    1.523890e+08  4.550514e+07           1.000000
# 75%    2.302709e+08  8.754595e+07           3.000000
# max    4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
onehotencoder=OneHotEncoder(categorical_features=[0])

# %%
data1.fillna(data1.mean(),inplace=True)

# %%
data1
# Out:
#         patient_nbr             race  gender      age  admission_type_id  \
# 0           8222157        Caucasian  Female   [0-10)                  6
# 1          55629189        Caucasian  Female  [10-20)                  1
# 2          86047875  AfricanAmerican  Female  [20-30)                  1
# 3          82442376        Caucasian    Male  [30-40)                  1
# 4          42519267        Caucasian    Male  [40-50)                  1
# ...             ...              ...     ...      ...                ...
# 101761    100162476  AfricanAmerican    Male  [70-80)                  1
# 101762     74694222  AfricanAmerican  Female  [80-90)                  1
# 101763     41088789        Caucasian    Male  [70-80)                  1
# 101764     31693671        Caucasian  Female  [80-90)                  2
# 101765    175429310        Caucasian    Male  [70-80)                  1
#
#         discharge_disposition_id  admission_source_id  time_in_hospital  \
# ...

# %%
from sklearn.preprocessing import OneHotEncoder
onehotencoder = OneHotEncoder(categorical_features = [0])

# %%
x = onehotencoder.fit_transform(x).toarray()
# Out:
# C:\Users\SriKavyaChintalapudi\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:450: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-4b0cf6256f65> in <module>
# ----> 1 x = onehotencoder.fit_transform(x).toarray()
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py in fit_transform(self, X, y)
#     626             return _transform_selected(
#     627                 X, self._legacy_fit_transform, self.dtype,
# --> 628                 self._categorical_features, copy=True)
#     629         else:
#     630             return self.fit(X).transform(X)
#
# ...

# %%
x = data1.iloc[:, 0:49].values
y = data1.iloc[:, 10].values

# %%
from sklearn.preprocessing import OneHotEncoder
onehotencoder = OneHotEncoder(categorical_features = [0])

# %%
X = x[:,1:]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =train_test_split(X, y,test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-866f485a8758> in <module>
#       1 from sklearn.linear_model import LinearRegression
#       2 regressor = LinearRegression()
# ----> 3 regressor.fit(X_train,y_train)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\base.py in fit(self, X, y, sample_weight)
#     461         n_jobs_ = self.n_jobs
#     462         X, y = check_X_y(X, y, accept_sparse=['csr', 'csc', 'coo'],
# --> 463                          y_numeric=True, multi_output=True)
#     464
#     465         if sample_weight is not None and np.atleast_1d(sample_weight).ndim > 1:
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc1 =StandardScaler()
X_train = sc1.fit_transform(X_train)
x_test = sc1.transform(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-50-34f7d347aee3> in <module>
#       1 from sklearn.preprocessing import StandardScaler
#       2 sc1 =StandardScaler()
# ----> 3 X_train = sc1.fit_transform(X_train)
#       4 x_test = sc1.transform(x_test)
#
# ~\anaconda3\lib\site-packages\sklearn\base.py in fit_transform(self, X, y, **fit_params)
#     551         if y is None:
#     552             # fit method of arity 1 (unsupervised transformation)
# --> 553             return self.fit(X, **fit_params).transform(X)
#     554         else:
#     555             # fit method of arity 2 (supervised transformation)
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\data.py in fit(self, X, y)
#     637         # Reset internal state before fitting
#     638         self._reset()
# --> 639         return self.partial_fit(X, y)
#     640
# ...

# %% [markdown]
# # Feature Scaling

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\SriKavyaChintalapudi\\Desktop\\remote internship 2020\\python code'

# %%
os.chdir("C:\\Users\\SriKavyaChintalapudi\\Desktop\\remote internship 2020\\python code")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\SriKavyaChintalapudi\\Desktop\\remote internship 2020\\python code'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data1=pd.read_csv("readmission.csv")

# %%
data1
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
# ...

# %%
dataf = pd.DataFrame()
dataf['features'] = numerics
dataf['std_dev'] = dataf['features'].apply(lambda x: data1[x].std())
dataf['mean'] = dataf['features'].apply(lambda x: data1[x].mean())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'number_emergency_log1p'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-116-061125ac2ede> in <module>
#       1 dataf = pd.DataFrame()
# ...

# %%
data2 = data1.drop_duplicates(subset= ['patient_nbr'], keep = 'first')
data2.shape
# Out:
# (71518, 50)

# %%
data1.describe()
# Out:
#        encounter_id   patient_nbr  admission_type_id  \
# count  1.017660e+05  1.017660e+05      101766.000000
# mean   1.652016e+08  5.433040e+07           2.024006
# std    1.026403e+08  3.869636e+07           1.445403
# min    1.252200e+04  1.350000e+02           1.000000
# 25%    8.496119e+07  2.341322e+07           1.000000
# 50%    1.523890e+08  4.550514e+07           1.000000
# 75%    2.302709e+08  8.754595e+07           3.000000
# max    4.438672e+08  1.895026e+08           8.000000
#
#        discharge_disposition_id  admission_source_id  time_in_hospital  \
# count             101766.000000        101766.000000     101766.000000
# mean                   3.715642             5.754437          4.395987
# std                    5.280166             4.064081          2.985108
# min                    1.000000             1.000000          1.000000
# 25%                    1.000000             1.000000          2.000000
# ...

# %%
data1.isnull().any()
# Out:
# encounter_id                False
# patient_nbr                 False
# race                        False
# gender                      False
# age                         False
# weight                      False
# admission_type_id           False
# discharge_disposition_id    False
# admission_source_id         False
# time_in_hospital            False
# payer_code                  False
# medical_specialty           False
# num_lab_procedures          False
# num_procedures              False
# num_medications             False
# number_outpatient           False
# number_emergency            False
# number_inpatient            False
# diag_1                      False
# diag_2                      False
# diag_3                      False
# number_diagnoses            False
# max_glu_serum               False
# A1Cresult                   False
# metformin                   False
# repaglinide                 False
# nateglinide                 False
# ...

# %%
data1=data1.drop('metformin-rosiglitazone',axis=1)
x=data1.iloc[0:,0:2].values
x
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-75-1c588ad093a4> in <module>
# ----> 1 data1=data1.drop('metformin-rosiglitazone',axis=1)
#       2 x=data1.iloc[0:,0:2].values
#       3 x
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
y=data1.iloc[0:,4].values
y
# Out:
# array(['[0-10)', '[10-20)', '[20-30)', ..., '[70-80)', '[80-90)',
#        '[70-80)'], dtype=object)

# %%
data1
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
m=MinMaxScaler()
x=m.fit_transform(x)
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-84-998fa98222db> in <module>
#       1 from sklearn.preprocessing import MinMaxScaler
#       2 m=MinMaxScaler()
# ----> 3 x=m.fit_transform(x)
#       4 x
#
# NameError: name 'x' is not defined

# %%
data1
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101754     443842016    183087545        Caucasian  Female  [70-80)      ?
# 101755     443842022    188574944            Other  Female  [40-50)      ?
# 101756     443842070    140199494            Other  Female  [60-70)      ?
# 101758     443842340    120975314        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
# ...

# %%
datf = pd.DataFrame()
datf['features'] = numerics
datf['std_dev'] = datf['features'].apply(lambda x: data1[x].std())
datf['mean'] = datf['features'].apply(lambda x: data1[x].mean())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'number_emergency_log1p'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-107-a6f8a1639d74> in <module>
#       1 datf = pd.DataFrame()
# ...

# %%
data1 = data1.drop_duplicates(subset= ['patient_nbr'], keep = 'first')
data1.shape
# Out:
# (71518, 50)

# %%
def standardize(raw_data):
    return ((raw_data - np.mean(raw_data, axis = 0)) / np.std(raw_data, axis = 0))

# %%
data1[numerics] = standardize(data1[numerics])
import scipy as sp
data1 = data1[(np.abs(sp.stats.zscore(data1[numerics])) < 3).all(axis=1)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-108-0c0f553d585f> in <module>
# ----> 1 data1[numerics] = standardize(data1[numerics])
#       2 import scipy as sp
#       3 data1 = data1[(np.abs(sp.stats.zscore(data1[numerics])) < 3).all(axis=1)]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
# ...

# %%
data1[numerics] = standardize(data1[numerics])
import scipy as sp
data1 = data1[(np.abs(sp.stats.zscore(data1[numerics])) < 3).all(axis=1)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-109-0c0f553d585f> in <module>
# ----> 1 data1[numerics] = standardize(data1[numerics])
#       2 import scipy as sp
#       3 data1 = data1[(np.abs(sp.stats.zscore(data1[numerics])) < 3).all(axis=1)]
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2804             if is_iterator(key):
#    2805                 key = list(key)
# -> 2806             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    2807
#    2808         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from matplotlib.colors import ListedColormap
my_cmap = ListedColormap(sns.light_palette((250, 100, 50), input="husl", n_colors=50).as_hex())
table = data2.drop(['patient_nbr', 'encounter_id'], axis=1).corr(method='pearson')
table.style.background_gradient(cmap=my_cmap, axis = 0)
# Out:
# <style  type="text/css" >
#     #T_89accbe8_98d2_11ea_b32a_e7b2169bdc76row0_col0 {
#             background-color:  #007ad1;
#             color:  #f1f1f1;
#         }    #T_89accbe8_98d2_11ea_b32a_e7b2169bdc76row0_col1 {
#             background-color:  #cee8fa;
#             color:  #000000;
#         }    #T_89accbe8_98d2_11ea_b32a_e7b2169bdc76row0_col2 {
#             background-color:  #b2d9f5;
#             color:  #000000;
#         }    #T_89accbe8_98d2_11ea_b32a_e7b2169bdc76row0_col3 {
#             background-color:  #e6f4ff;
#             color:  #000000;
#         }    #T_89accbe8_98d2_11ea_b32a_e7b2169bdc76row0_col4 {
#             background-color:  #e6f4ff;
#             color:  #000000;
#         }    #T_89accbe8_98d2_11ea_b32a_e7b2169bdc76row0_col5 {
#             background-color:  #b2d9f5;
#             color:  #000000;
#         }    #T_89accbe8_98d2_11ea_b32a_e7b2169bdc76row0_col6 {
#             background-color:  #c5e3f8;
#             color:  #000000;
# ...

# %%
data['level1_diag1'] = data1['level1_diag1'].astype('object')
data_pd = pd.get_dummies(data1, columns=['gender', 'admission_type_id', 'discharge_disposition_id',
                                      'admission_source_id', 'max_glu_serum', 'A1Cresult', 'level1_diag1'], drop_first = True)
just_dummies = pd.get_dummies(data_pd['race'])
data_pd = pd.concat([data1_pd, just_dummies], axis=1)      
data_pd.drop(['race'], inplace=True, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'level1_diag1'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-111-5062d82bb4bd> in <module>
# ...

# %%
non_num_cols = ['race', 'gender', 'admission_type_id', 'discharge_disposition_id', 'admission_source_id', 
                'max_glu_serum', 'A1Cresult', 'level1_diag1' ]

# %%
num_cols = list(set(list(data1._get_numeric_data().columns))- {'readmitted', 'change'})
num_cols
# Out:
# ['num_procedures',
#  'admission_source_id',
#  'admission_type_id',
#  'patient_nbr',
#  'discharge_disposition_id',
#  'encounter_id',
#  'number_emergency',
#  'number_diagnoses',
#  'num_medications',
#  'number_outpatient',
#  'time_in_hospital',
#  'number_inpatient',
#  'num_lab_procedures']

# %%
new_non_num_cols = []
for i in non_num_cols:
    for j in data1_pd.columns:
        if i in j:
            new_non_num_cols.append(j)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-112-bfa51250797f> in <module>
#       1 new_non_num_cols = []
#       2 for i in non_num_cols:
# ----> 3     for j in data1_pd.columns:
#       4         if i in j:
#       5             new_non_num_cols.append(j)
#
# NameError: name 'data1_pd' is not defined

# %%
new_non_num_cols
# Out:
# []

# %%
l = []
for feature in list(data1_pd.columns):
    if '|' in feature:
        l.append(feature)
l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-113-4bb05bb6bf0e> in <module>
#       1 l = []
# ----> 2 for feature in list(data1_pd.columns):
#       3     if '|' in feature:
#       4         l.append(feature)
#       5 l
#
# NameError: name 'data1_pd' is not defined

# %%
df_pd.head().T
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-121-c0f6d883f4d9> in <module>
# ----> 1 df_pd.head().T
#
# NameError: name 'df_pd' is not defined

# %% [markdown]
# # Splitting Data into Train and Test

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\SriKavyaChintalapudi\\Desktop\\remote internship 2020\\python code'

# %%
os.chdir('C:\\Users\\SriKavyaChintalapudi\\Desktop\\remote internship 2020\\python code')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\SriKavyaChintalapudi\\Desktop\\remote internship 2020\\python code'

# %%
import numpy as np
import pandas as pd

# %%
data1=pd.read_csv("readmission.csv")

# %%
data1
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 0            2278392      8222157        Caucasian  Female   [0-10)      ?
# 1             149190     55629189        Caucasian  Female  [10-20)      ?
# 2              64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3             500364     82442376        Caucasian    Male  [30-40)      ?
# 4              16680     42519267        Caucasian    Male  [40-50)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101761     443847548    100162476  AfricanAmerican    Male  [70-80)      ?
# 101762     443847782     74694222  AfricanAmerican  Female  [80-90)      ?
# 101763     443854148     41088789        Caucasian    Male  [70-80)      ?
# 101764     443857166     31693671        Caucasian  Female  [80-90)      ?
# 101765     443867222    175429310        Caucasian    Male  [70-80)      ?
#
# ...

# %%
data1=data1.drop('metformin-rosiglitazone',axis=1)
x=data1.iloc[0:,0:3].values
x
# Out:
# array([[2278392, 8222157, 'Caucasian'],
#        [149190, 55629189, 'Caucasian'],
#        [64410, 86047875, 'AfricanAmerican'],
#        ...,
#        [443854148, 41088789, 'Caucasian'],
#        [443857166, 31693671, 'Caucasian'],
#        [443867222, 175429310, 'Caucasian']], dtype=object)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score
print("Accuracy is {0:.2f}".format(accuracy_score(y_test, logit_pred)))
print("Precision is {0:.2f}".format(precision_score(y_test, logit_pred)))
print("Recall is {0:.2f}".format(recall_score(y_test, logit_pred)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-129-ac685ad63e2c> in <module>
#       1 from sklearn.metrics import accuracy_score, precision_score, recall_score
# ----> 2 print("Accuracy is {0:.2f}".format(accuracy_score(y_test, logit_pred)))
#       3 print("Precision is {0:.2f}".format(precision_score(y_test, logit_pred)))
#       4 print("Recall is {0:.2f}".format(recall_score(y_test, logit_pred)))
#
# NameError: name 'y_test' is not defined

# %%
y=data1.iloc[0:,2].values
y
# Out:
# array(['Caucasian', 'Caucasian', 'AfricanAmerican', ..., 'Caucasian',
#        'Caucasian', 'Caucasian'], dtype=object)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
x_train
# Out:
# array([[13844448, 13324851, 'Caucasian'],
#        [334858352, 96035814, 'Caucasian'],
#        [76681488, 21027366, 'Caucasian'],
#        ...,
#        [131402904, 23453532, 'AfricanAmerican'],
#        [134521350, 84181878, 'Other'],
#        [192563658, 104363523, 'Caucasian']], dtype=object)

# %%
y_train
# Out:
# array(['Caucasian', 'Caucasian', 'Caucasian', ..., 'AfricanAmerican',
#        'Other', 'Caucasian'], dtype=object)

# %%
x_test
# Out:
# array([[134140482, 88421031, 'Caucasian'],
#        [106194426, 23205420, 'AfricanAmerican'],
#        [103343040, 23241960, 'Caucasian'],
#        ...,
#        [213521814, 111845718, 'Caucasian'],
#        [31922232, 3692376, 'Caucasian'],
#        [229574442, 87284187, 'Caucasian']], dtype=object)

# %%
y_test
# Out:
# array(['Caucasian', 'AfricanAmerican', 'Caucasian', ..., 'Caucasian',
#        'Caucasian', 'Caucasian'], dtype=object)

# %%
logit_pred = logit.predict(X_test)
pd.crosstab(pd.Series(y_test, name = 'Actual'), pd.Series(logit_pred, name = 'Predict'), margins = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-123-fe0875beae38> in <module>
# ----> 1 logit_pred = logit.predict(X_test)
#       2 pd.crosstab(pd.Series(y_test, name = 'Actual'), pd.Series(logit_pred, name = 'Predict'), margins = True)
#
# NameError: name 'logit' is not defined

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter
print('Original dataset shape {}'.format(Counter(y_train)))
sm = SMOTE(random_state=20)
train_input_new, train_output_new = sm.fit_sample(X_train, y_train)
print('New dataset shape {}'.format(Counter(train_output_new)))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-130-4d73fb57a377> in <module>
# ----> 1 from imblearn.over_sampling import SMOTE
#       2 from collections import Counter
#       3 print('Original dataset shape {}'.format(Counter(y_train)))
#       4 sm = SMOTE(random_state=20)
#       5 train_input_new, train_output_new = sm.fit_sample(X_train, y_train)
#
# ModuleNotFoundError: No module named 'imblearn'

# %%
train_input_new = pd.DataFrame(train_input_new, columns = list(X.columns))
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
X_train, X_test, y_train, y_test = train_test_split(train_input_new, train_output_new, test_size=0.20, random_state=0)
logit = LogisticRegression(fit_intercept=True, penalty='l2')
logit.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-131-1183a36b75a1> in <module>
# ----> 1 train_input_new = pd.DataFrame(train_input_new, columns = list(X.columns))
#       2 from sklearn.model_selection import train_test_split
#       3 from sklearn.linear_model import LogisticRegression
#       4 from sklearn.model_selection import cross_val_score
#       5 X_train, X_test, y_train, y_test = train_test_split(train_input_new, train_output_new, test_size=0.20, random_state=0)
#
# NameError: name 'train_input_new' is not defined

# %%
logit_pred = logit.predict(X_test)
pd.crosstab(pd.Series(y_test, name = 'Actual'), pd.Series(logit_pred, name = 'Predict'), margins = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-132-fe0875beae38> in <module>
# ----> 1 logit_pred = logit.predict(X_test)
#       2 pd.crosstab(pd.Series(y_test, name = 'Actual'), pd.Series(logit_pred, name = 'Predict'), margins = True)
#
# NameError: name 'logit' is not defined

# %%
print("Accuracy is {0:.2f}".format(accuracy_score(y_test, logit_pred)))
print("Precision is {0:.2f}".format(precision_score(y_test, logit_pred)))
print("Recall is {0:.2f}".format(recall_score(y_test, logit_pred)))

accuracy_logit = accuracy_score(y_test, logit_pred)
precision_logit = precision_score(y_test, logit_pred)
recall_logit = recall_score(y_test, logit_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-133-2fff40a1416c> in <module>
# ----> 1 print("Accuracy is {0:.2f}".format(accuracy_score(y_test, logit_pred)))
#       2 print("Precision is {0:.2f}".format(precision_score(y_test, logit_pred)))
#       3 print("Recall is {0:.2f}".format(recall_score(y_test, logit_pred)))
#       4
#       5 accuracy_logit = accuracy_score(y_test, logit_pred)
#
# NameError: name 'y_test' is not defined

# %% [markdown]
# # MODEL BUILDING

# %% [markdown]
# # Modeling

# %%
feature_set = ['age', 'time_in_hospital', 'num_procedures', 'num_medications', 'number_outpatient_log1p', 
                 'number_emergency_log1p', 'number_inpatient_log1p', 'number_diagnoses', 'metformin', 
                 'repaglinide', 'nateglinide', 'chlorpropamide', 'glimepiride', 'glipizide', 'glyburide',
                 'pioglitazone', 'rosiglitazone', 'acarbose', 'tolazamide', 'insulin', 'glyburide-metformin',
                 'AfricanAmerican', 'Asian', 'Caucasian', 'Hispanic', 'Other', 'gender_1', 
                 'admission_type_id_3', 'admission_type_id_5', 'discharge_disposition_id_2', 'discharge_disposition_id_7', 
                 'discharge_disposition_id_10', 'discharge_disposition_id_18', 'admission_source_id_4',
                 'admission_source_id_7', 'admission_source_id_9', 'max_glu_serum_0', 'max_glu_serum_1', 'A1Cresult_0',
                 'A1Cresult_1', 'num_medications|time_in_hospital', 'num_medications|num_procedures',
                 'time_in_hospital|num_lab_procedures', 'num_medications|num_lab_procedures', 'num_medications|number_diagnoses',
                 'age|number_diagnoses', 'change|num_medications', 'number_diagnoses|time_in_hospital',
                 'num_medications|numchange', 'level1_diag1_1.0', 'level1_diag1_2.0', 'level1_diag1_3.0', 'level1_diag1_4.0',
                 'level1_diag1_5.0','level1_diag1_6.0', 'level1_diag1_7.0', 'level1_diag1_8.0']

# %%
X = data1_pd[feature_set]
y = data1_pd['readmitted']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-136-732e2d3d617c> in <module>
# ----> 1 X = data1_pd[feature_set]
#       2 y = data1_pd['readmitted']
#
# NameError: name 'data1_pd' is not defined

# %% [markdown]
# # Training and testing the model

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)
logit = LogisticRegression(fit_intercept=True, penalty='l2')
logit.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-137-0928bc6caae5> in <module>
#       2 from sklearn.linear_model import LogisticRegression
#       3 from sklearn.model_selection import cross_val_score
# ----> 4 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=0)
#       5 logit = LogisticRegression(fit_intercept=True, penalty='l2')
#       6 logit.fit(X_train, y_train)
#
# NameError: name 'X' is not defined

# %%
logit_pred = logit.predict(X_test)
pd.crosstab(pd.Series(y_test, name = 'Actual'), pd.Series(logit_pred, name = 'Predict'), margins = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-138-fe0875beae38> in <module>
# ----> 1 logit_pred = logit.predict(X_test)
#       2 pd.crosstab(pd.Series(y_test, name = 'Actual'), pd.Series(logit_pred, name = 'Predict'), margins = True)
#
# NameError: name 'logit' is not defined

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score
print("Accuracy is {0:.2f}".format(accuracy_score(y_test, logit_pred)))
print("Precision is {0:.2f}".format(precision_score(y_test, logit_pred)))
print("Recall is {0:.2f}".format(recall_score(y_test, logit_pred)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-139-ac685ad63e2c> in <module>
#       1 from sklearn.metrics import accuracy_score, precision_score, recall_score
# ----> 2 print("Accuracy is {0:.2f}".format(accuracy_score(y_test, logit_pred)))
#       3 print("Precision is {0:.2f}".format(precision_score(y_test, logit_pred)))
#       4 print("Recall is {0:.2f}".format(recall_score(y_test, logit_pred)))
#
# NameError: name 'y_test' is not defined

# %%
from imblearn.over_sampling import SMOTE
from collections import Counter
print('Original dataset shape {}'.format(Counter(y_train)))
sm = SMOTE(random_state=20)
train_input_new, train_output_new = sm.fit_sample(X_train, y_train)
print('New dataset shape {}'.format(Counter(train_output_new)))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-140-4d73fb57a377> in <module>
# ----> 1 from imblearn.over_sampling import SMOTE
#       2 from collections import Counter
#       3 print('Original dataset shape {}'.format(Counter(y_train)))
#       4 sm = SMOTE(random_state=20)
#       5 train_input_new, train_output_new = sm.fit_sample(X_train, y_train)
#
# ModuleNotFoundError: No module named 'imblearn'

# %%
train_input_new = pd.DataFrame(train_input_new, columns = list(X.columns))
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
X_train, X_test, y_train, y_test = train_test_split(train_input_new, train_output_new, test_size=0.20, random_state=0)
logit = LogisticRegression(fit_intercept=True, penalty='l2')
logit.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-141-1183a36b75a1> in <module>
# ----> 1 train_input_new = pd.DataFrame(train_input_new, columns = list(X.columns))
#       2 from sklearn.model_selection import train_test_split
#       3 from sklearn.linear_model import LogisticRegression
#       4 from sklearn.model_selection import cross_val_score
#       5 X_train, X_test, y_train, y_test = train_test_split(train_input_new, train_output_new, test_size=0.20, random_state=0)
#
# NameError: name 'train_input_new' is not defined

# %%
logit_pred = logit.predict(X_test)
pd.crosstab(pd.Series(y_test, name = 'Actual'), pd.Series(logit_pred, name = 'Predict'), margins = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-142-fe0875beae38> in <module>
# ----> 1 logit_pred = logit.predict(X_test)
#       2 pd.crosstab(pd.Series(y_test, name = 'Actual'), pd.Series(logit_pred, name = 'Predict'), margins = True)
#
# NameError: name 'logit' is not defined

# %%
print("Accuracy is {0:.2f}".format(accuracy_score(y_test, logit_pred)))
print("Precision is {0:.2f}".format(precision_score(y_test, logit_pred)))
print("Recall is {0:.2f}".format(recall_score(y_test, logit_pred)))

accuracy_logit = accuracy_score(y_test, logit_pred)
precision_logit = precision_score(y_test, logit_pred)
recall_logit = recall_score(y_test, logit_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-143-2fff40a1416c> in <module>
# ----> 1 print("Accuracy is {0:.2f}".format(accuracy_score(y_test, logit_pred)))
#       2 print("Precision is {0:.2f}".format(precision_score(y_test, logit_pred)))
#       3 print("Recall is {0:.2f}".format(recall_score(y_test, logit_pred)))
#       4
#       5 accuracy_logit = accuracy_score(y_test, logit_pred)
#
# NameError: name 'y_test' is not defined
